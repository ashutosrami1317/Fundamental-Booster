# %%
print("Welcome to the Interactive personal Data collector!")

name = input("Please enter your name:")
age = int(input("Please enter your age:"))
hegiht = float(input("Please enter your height in meters:"))
fav_number = int(input("Please enter your favourite number:"))

print("\nThank you! Prcossing your data...\n")

current_year = 2026
birth_year = current_year - age 

rounded_height = int(hegiht)

print("Variable details")
print(f"Name : {name} (Type: {type(name)}, Memory Address: {id(name)})")
print(f"Age : {age} (Type: {type(age)}, Memory Address: {id(age)})")
print(f"Height : {hegiht} (Type: {type(hegiht)}, Memory Address: {id(hegiht)})")
print(f"Favourite Number : {fav_number} (Type: {type(fav_number)}, Memory Address: {id(fav_number)})")

print("\n Summary ")
print(f"Hello {name}, here is your information. ")
print(f"Age: {age}")
print(f"Height: {hegiht} meters")
print(f"Favourite Number: {fav_number}")

print(f"\nYour birth year is approximately: {birth_year} (based on your age of {age})")

print(f"\nYour height rounded down to nearest integer is: {rounded_height}")
print("This value was converted from float to integer using type casting.")

print(" Thank you for using the Personal Data Collector. Goodbye!")
# Out:
# Welcome to the Interactive personal Data collector!
# Please enter your name: Alice
# Please enter your age: 25
# Please enter your height in meters: 1.68
# Please enter your favourite number: 7
# Thank you! Prcossing your data...
#
# Variable details
# Name : Alice (Type: <class 'str'>, Memory Address: 2598411714448)
# Age : 25 (Type: <class 'int'>, Memory Address: 140726252578472)
# Height : 1.68 (Type: <class 'float'>, Memory Address: 2598409789104)
# Favourite Number : 7 (Type: <class 'int'>, Memory Address: 140726252577896)
#
#  Summary
# Hello Alice, here is your information.
# Age: 25
# Height: 1.68 meters
# Favourite Number: 7
#
# Your birth year is approximately: 2001 (based on your age of 25)
#
# Your height rounded down to nearest integer is: 1
# This value was converted from float to integer using type casting.
#  Thank you for using the Personal Data Collector. Goodbye!
