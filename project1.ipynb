# %% [markdown]
# <h1 style="font-size:40px;">Welcome to the interative personal Data collector</h1>

# %%
print("Hello")
# Out:
# Hello

# %%
username = "Ashutosh"
print("Hello,"+username)
# Out:
# Hello,Ashutosh

# %%
age = int(input("Enter your age: ")) # Conerts input to n iteger
height = float(input("Enter your height in meters: "))  # Conerts to flote

print(" you are", age , "years old and", height,"meters tall")
# Out:
# Enter your age:  21
# Enter your height in meters:  165
#  you are 21 years old and 165.0 meters tall

# %%
id = 12557
name = "Ashutosh Rami"
isAuth = True
courses = ["Python","ML","AI","Data Science"]

print("Id:",id)
# Out:
# Id: 12557

# %%
data=10
print(data) #data is of typs integer
data="python"
print(data) # data is now type string
# Out:
# 10
# python

# %% [markdown]
# a = 60 # int
# b = 70.80 # flot
# c = 'SCIENCE' # char #STR

# %%
print(a)
print(b)
print(c)
# Out:
# 60
# 70.8
# SCIENCE

# %%
_A = 10 #int
b = " Ariticial Intelligence" #string
X = 40.90 #flot

print(_A) # datadype
print(b)
print(X)
# Out:
# 10
#  Ariticial Intelligence
# 40.9

# %%
A,B,C,D,E = 40,50,20,"Robotics",50.90 # simulation variable"


X,Y,Z = 30,"Ashutosh",90.99 


print(A)
print(B)
print(c)
print("*****")
print(X)
print(Y)
print(Z)
# Out:
# 40
# 50
# SCIENCE
# *****
# 30
# Ashutosh
# 90.99

# %% [markdown]
# <h1>Implicit Type conversion</h1>

# %%
#python automatically canverts
num1 = int(input("Enter num1:"))
num2 = int(input("Enter num2:"));
print("Addition : ",num1+num2);
# Out:
# Enter num1: 5
# Enter num2: 2
# Addition :  7

# %%
#python automaticlly converts
# a to int 
a = 7
print(type(a))
# Out:
# <class 'int'>

# %%
#python automaticlly converts
# b to float
b = 4.0
print(type(b))
# Out:
# <class 'float'>

# %%
#python automaticlly converts
# c to float as it is a float addition
c = a + b
print(c)
print(type(c))
# Out:
# 11.0
# <class 'float'>

# %%
#python automaticlly converts
# d to float as it is a float muitiplication
d= a*b
print(d)
print(type(d))
# Out:
# 28.0
# <class 'float'>

# %% [markdown]
# *int to flote datarype

# %%
A = 5
# typecast to float
B = float(A)
print(B)
print (type(B))
# Out:
# 5.0
# <class 'float'>

# %% [markdown]
# *Float to int datatype

# %%
a = 6.5

# typecast to int
h = int(a)
print(h)
print(type(h))
# Out:
# 6
# <class 'int'>

# %% [markdown]
# *int to string datatype

# %%
a = 5

#typecast to str
n =str(a)

print(n)
print(type(n))
# Out:
# 5
# <class 'str'>

# %% [markdown]
# *string into float datatype

# %%
a = "5.9"

# typecast to float
b= float(a)
print(b)
print(type(b))
# Out:
# 5.9
# <class 'float'>

# %% [markdown]
# *string to int datatype

# %%
a="6"
b="d"

# typecast to int
n = int(a)


print(n)
print(type(n))

print (b)
print(type(b))
# Out:
# 6
# <class 'int'>
# d
# <class 'str'>

# %% [markdown]
# * Arithmetic Operator

# %%
# Taking two numbers a and b

a = 8
b = 4
print(a)
print(b)

print("id of a variable")
print(id(a))
print(id(b))
# Out:
# 8
# 4
# id of a variable
# 140732746409096
# 140732746408968

# %%
# Addition
a = 4
b = 5

addition = a + b
print(addition)
# Out:
# 9

# %%
# subtraction
a = 13
b = 45

subtraction = a - b
print (subtraction)
# Out:
# -32

# %%
# Division
a = 23
b = 12

division = a / b
print(division)
# Out:
# 1.9166666666666667

# %%
# Exponential power

a = 23
b = 12

exponential = a**b
print(exponential)
# Out:
# 21914624432020321

# %% [markdown]
# <h1 style="font-size:40px;">Thank you for using the personal Data collector. Goodbye!</h1>
